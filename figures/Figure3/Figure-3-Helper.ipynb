# %% [markdown]
# ## **Figure-3-Helper**

# %%
import pandas as pd
import polars as pl
import sys
import sqlite3
from collections import defaultdict

sys.path.append("../../scripts")

from figure_utils import *

# %%
print("Pandas Version", pd.__version__)
print("Polars Version", pl.__version__)
print("Python Version", sys.version)
# Out:
# Pandas Version 2.2.3
# Polars Version 1.28.1
# Python Version 3.12.4 (main, Jun  7 2024, 23:47:47) [GCC 13.3.0]

# %%
names = dict(exp='Experimental',
             silico='in-silico',
             bruker='timsTOF, 2024',
             panhuman='PanHuman, 2014')

condition = dict(orig='Initial', refined='Reconstructed', tl='Transfer-Learn')

# %%
osw_frag_intens = defaultdict(dict)

# Bruker data
parquet_file = "../../results/K562-Bruker-Library-Analysis/osw/Rost_DIApy3_SP2um_90min_250ngK562_100nL_1_Slot1-5_1_1330_6-28-2021/pyprophet_XGB/Rost_DIApy3_SP2um_90min_250ngK562_100nL_1_Slot1-5_1_1330_6-28-2021.parquet"
osw_file = "../../results/K562-Bruker-Library-Analysis/osw/Rost_DIApy3_SP2um_90min_250ngK562_100nL_1_Slot1-5_1_1330_6-28-2021/pyprophet_XGB/Rost_DIApy3_SP2um_90min_250ngK562_100nL_1_Slot1-5_1_1330_6-28-2021.osw"
osw_frag_intens[names['bruker']][condition['orig']] = compute_frag_intensity_residuals(parquet_file, osw_file)

parquet_file = "../../results/K562-Bruker-Lib-Refined-GPF-Analysis/osw/Rost_DIApy3_SP2um_90min_250ngK562_100nL_1_Slot1-5_1_1330_6-28-2021/pyprophet_XGB/Rost_DIApy3_SP2um_90min_250ngK562_100nL_1_Slot1-5_1_1330_6-28-2021.parquet"
osw_file = "../../results/K562-Bruker-Lib-Refined-GPF-Analysis/osw/Rost_DIApy3_SP2um_90min_250ngK562_100nL_1_Slot1-5_1_1330_6-28-2021/pyprophet_XGB/Rost_DIApy3_SP2um_90min_250ngK562_100nL_1_Slot1-5_1_1330_6-28-2021.osw"
osw_frag_intens[names['bruker']][condition['refined']] = compute_frag_intensity_residuals(parquet_file, osw_file)

osw_frag_intens[names['bruker']][condition['tl']] = compute_frag_intensity_residuals_oswpq("../../results/K562-Bruker-Lib-Refined-GPF-Analysis/osw_tl/Rost_DIApy3_SP2um_90min_250ngK562_100nL_1_Slot1-5_1_1330_6-28-2021/pyprophet_XGB/Rost_DIApy3_SP2um_90min_250ngK562_100nL_1_Slot1-5_1_1330_6-28-2021.oswpq/")

# Panhuman data
osw_frag_intens[names['panhuman']][condition['orig']] = compute_frag_intensity_residuals_oswpq("../../results/K562-PanHuman-Analysis/osw/Rost_DIApy3_SP2um_90min_250ngK562_100nL_1_Slot1-5_1_1330_6-28-2021/pyprophet_SVM/Rost_DIApy3_SP2um_90min_250ngK562_100nL_1_Slot1-5_1_1330_6-28-2021.oswpq/", norm_factor=10000)
osw_frag_intens[names['panhuman']][condition['refined']] = compute_frag_intensity_residuals_oswpq("../../results/K562-PanHuman-Lib-Refined-GPF-Analysis/osw/Rost_DIApy3_SP2um_90min_250ngK562_100nL_1_Slot1-5_1_1330_6-28-2021/pyprophet_SVM/Rost_DIApy3_SP2um_90min_250ngK562_100nL_1_Slot1-5_1_1330_6-28-2021.oswpq/", norm_factor=10000)
osw_frag_intens[names['panhuman']][condition['tl'] ] = compute_frag_intensity_residuals_oswpq("../../results/K562-PanHuman-Lib-Refined-GPF-Analysis/osw_tl/Rost_DIApy3_SP2um_90min_250ngK562_100nL_1_Slot1-5_1_1330_6-28-2021/pyprophet_SVM/Rost_DIApy3_SP2um_90min_250ngK562_100nL_1_Slot1-5_1_1330_6-28-2021.oswpq/")

# Experimental data
parquet_file = "../../results/K562-Exp-Lib-Analysis/osw/Rost_DIApy3_SP2um_90min_250ngK562_100nL_1_Slot1-5_1_1330_6-28-2021/pyprophet_XGB/Rost_DIApy3_SP2um_90min_250ngK562_100nL_1_Slot1-5_1_1330_6-28-2021.parquet"
osw_file = "../../results/K562-Exp-Lib-Analysis/osw/Rost_DIApy3_SP2um_90min_250ngK562_100nL_1_Slot1-5_1_1330_6-28-2021/pyprophet_XGB/Rost_DIApy3_SP2um_90min_250ngK562_100nL_1_Slot1-5_1_1330_6-28-2021.osw"
osw_frag_intens[names['exp']][condition['orig']] = compute_frag_intensity_residuals(parquet_file, osw_file)

parquet_file = "../../results/K562-Exp-Lib-Refined-GPF-Analysis/osw/Rost_DIApy3_SP2um_90min_250ngK562_100nL_1_Slot1-5_1_1330_6-28-2021/pyprophet_XGB/Rost_DIApy3_SP2um_90min_250ngK562_100nL_1_Slot1-5_1_1330_6-28-2021.parquet"
osw_file = "../../results/K562-Exp-Lib-Refined-GPF-Analysis/osw/Rost_DIApy3_SP2um_90min_250ngK562_100nL_1_Slot1-5_1_1330_6-28-2021/pyprophet_XGB/Rost_DIApy3_SP2um_90min_250ngK562_100nL_1_Slot1-5_1_1330_6-28-2021.osw"
osw_frag_intens[names['exp']][condition['refined']] = compute_frag_intensity_residuals(parquet_file, osw_file)

osw_frag_intens[names['exp']][condition['tl']] = compute_frag_intensity_residuals_oswpq("../../results/K562-Exp-Lib-Refined-GPF-Analysis/osw_tl/Rost_DIApy3_SP2um_90min_250ngK562_100nL_1_Slot1-5_1_1330_6-28-2021/pyprophet_XGB/Rost_DIApy3_SP2um_90min_250ngK562_100nL_1_Slot1-5_1_1330_6-28-2021.oswpq/")

# Silico data
osw_frag_intens[names['silico']][condition['orig']] = compute_frag_intensity_residuals_oswpq("../../results/K562-PeptDeep-NoMods-Analysis/osw/Rost_DIApy3_SP2um_90min_250ngK562_100nL_1_Slot1-5_1_1330_6-28-2021/pyprophet_XGB/Rost_DIApy3_SP2um_90min_250ngK562_100nL_1_Slot1-5_1_1330_6-28-2021.oswpq")

parquet_file = "../../results/K562-PeptDeep-NoMods-Lib-Refined-GPF-Analysis/osw/Rost_DIApy3_SP2um_90min_250ngK562_100nL_1_Slot1-5_1_1330_6-28-2021/pyprophet_XGB/Rost_DIApy3_SP2um_90min_250ngK562_100nL_1_Slot1-5_1_1330_6-28-2021.parquet"
osw_file = "../../results/K562-PeptDeep-NoMods-Lib-Refined-GPF-Analysis/osw/Rost_DIApy3_SP2um_90min_250ngK562_100nL_1_Slot1-5_1_1330_6-28-2021/pyprophet_XGB/Rost_DIApy3_SP2um_90min_250ngK562_100nL_1_Slot1-5_1_1330_6-28-2021.osw"
osw_frag_intens[names['silico']][condition['refined']] = compute_frag_intensity_residuals(parquet_file, osw_file)

osw_frag_intens[names['silico']][condition['tl'] ] = compute_frag_intensity_residuals_oswpq("../../results/K562-PeptDeep-NoMods-Lib-Refined-GPF-Analysis/osw_tl/Rost_DIApy3_SP2um_90min_250ngK562_100nL_1_Slot1-5_1_1330_6-28-2021/pyprophet_XGB/Rost_DIApy3_SP2um_90min_250ngK562_100nL_1_Slot1-5_1_1330_6-28-2021.oswpq")
# Out:
# ../../results/K562-Bruker-Library-Analysis/osw/Rost_DIApy3_SP2um_90min_250ngK562_100nL_1_Slot1-5_1_1330_6-28-2021/pyprophet_XGB/Rost_DIApy3_SP2um_90min_250ngK562_100nL_1_Slot1-5_1_1330_6-28-2021.parquet
# ../../results/K562-Bruker-Lib-Refined-GPF-Analysis/osw/Rost_DIApy3_SP2um_90min_250ngK562_100nL_1_Slot1-5_1_1330_6-28-2021/pyprophet_XGB/Rost_DIApy3_SP2um_90min_250ngK562_100nL_1_Slot1-5_1_1330_6-28-2021.parquet
# ../../results/K562-Bruker-Lib-Refined-GPF-Analysis/osw_tl/Rost_DIApy3_SP2um_90min_250ngK562_100nL_1_Slot1-5_1_1330_6-28-2021/pyprophet_XGB/Rost_DIApy3_SP2um_90min_250ngK562_100nL_1_Slot1-5_1_1330_6-28-2021.oswpq/
# ../../results/K562-PanHuman-Analysis/osw/Rost_DIApy3_SP2um_90min_250ngK562_100nL_1_Slot1-5_1_1330_6-28-2021/pyprophet_SVM/Rost_DIApy3_SP2um_90min_250ngK562_100nL_1_Slot1-5_1_1330_6-28-2021.oswpq/
# ...

# %%
tmp = {}
for k, v in osw_frag_intens.items():
    tmp[k] = pd.concat(v).reset_index(names=['Condition', 'i']).drop(columns='i')
    
osw_df_frags = pd.concat(tmp).reset_index(names=['Library', 'i']).drop(columns='i')

# %%
osw_df_frags.to_csv("osw-df-frags.tsv", sep='\t', index=False)
